# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import statsmodels.api as sm
from pandas import DataFrame , concat
from sklearn.metrics import mean_absolute_error , mean_squared_error
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
from numpy import mean , concatenate
from math import sqrt
from pandas import read_csv
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,LSTM,Activation
from numpy import array , hstack
from tensorflow import keras
import tensorflow as tf
# if you're using google drive to store the dataset
from google.colab import drive
drive.mount('/content/drive')
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# Mounted at /content/drive

# %%
url = '/content/drive/MyDrive/Colab Notebooks/Datasets/Dataset.csv'
dataset = pd.read_csv(url)
x_1 = dataset['x1']
x_2 = dataset['x2']
y = dataset['y']
x_1 = x_1.values
x_2 = x_2.values
y = y.values
plt.figure(figsize=(30, 6))
plt.plot(x_1[:10064] , label='x1')
plt.plot(x_2[:10064] , label='x2')
plt.plot(y[:10064] , label='y')
plt.legend(loc='upper right')
plt.title("Dataset" ,  fontsize=18)
plt.xlabel('Time step' ,  fontsize=18)
plt.ylabel('Values' , fontsize=18)
plt.legend()
plt.show()

# %%
# Step 1 : convert to [rows, columns] structure
x_1 = x_1.reshape((len(x_1), 1))
x_2 = x_2.reshape((len(x_2), 1))
y = y.reshape((len(y), 1))
print ("x_1.shape" , x_1.shape) 
print ("x_2.shape" , x_2.shape) 
print ("y.shape" , y.shape)
# Step 2 : normalization 
scaler = MinMaxScaler(feature_range=(0, 1))
x_1_scaled = scaler.fit_transform(x_1)
x_2_scaled = scaler.fit_transform(x_2)
y_scaled = scaler.fit_transform(y)
# Step 3 : horizontally stack columns
dataset_stacked = hstack((x_1_scaled, x_2_scaled, y_scaled))
print ("dataset_stacked.shape" , dataset_stacked.shape)
# Out:
# x_1.shape (35224, 1)
# x_2.shape (35224, 1)
# y.shape (35224, 1)
# dataset_stacked.shape (35224, 3)

# %%
# split a multivariate sequence into samples
def split_sequences(sequences, n_steps_in, n_steps_out):
 X, y = list(), list()
 for i in range(len(sequences)):
  # find the end of this pattern
  end_ix = i + n_steps_in
  out_end_ix = end_ix + n_steps_out-1
  # check if we are beyond the dataset
  if out_end_ix > len(sequences):
   break
  # gather input and output parts of the pattern
  seq_x, seq_y = sequences[i:end_ix, :-1], sequences[end_ix-1:out_end_ix, -1]
  X.append(seq_x)
  y.append(seq_y)
 return array(X), array(y)
# choose a number of time steps #change this accordingly
n_steps_in, n_steps_out = 60 , 30
# covert into input/output
X, y = split_sequences(dataset_stacked, n_steps_in, n_steps_out)
print ("X.shape" , X.shape) 
print ("y.shape" , y.shape)
# Out:
# X.shape (35136, 60, 2)
# y.shape (35136, 30)

# %%
split_point = 1258*25
train_X , train_y = X[:split_point, :] , y[:split_point, :]
test_X , test_y = X[split_point:, :] , y[split_point:, :]

# %%
#optimizer learning rate
opt = keras.optimizers.Adam(learning_rate=0.0001)
# define model
model = Sequential()
# model.add(LSTM(50, activation='relu', return_sequences=True, input_shape=(n_steps_in, n_features)))
model.add(LSTM(50, activation='relu'))
model.add(Dense(n_steps_out))
model.add(Activation('linear'))
model.compile(loss='mse' , optimizer=opt , metrics=['mse'])

# %%
# Fit network
history = model.fit(train_X , train_y , epochs=60 , steps_per_epoch=25 , verbose=1 ,validation_data=(test_X, test_y) ,shuffle=False)
# Out:
# Epoch 1/60
# 25/25 [==============================] - 8s 288ms/step - loss: 0.1052 - mse: 0.1052 - val_loss: 0.0963 - val_mse: 0.0963
# Epoch 2/60
# 25/25 [==============================] - 7s 278ms/step - loss: 0.0986 - mse: 0.0986 - val_loss: 0.0898 - val_mse: 0.0898
# Epoch 3/60
# 25/25 [==============================] - 7s 278ms/step - loss: 0.0916 - mse: 0.0916 - val_loss: 0.0823 - val_mse: 0.0823
# Epoch 4/60
# 25/25 [==============================] - 7s 276ms/step - loss: 0.0835 - mse: 0.0835 - val_loss: 0.0731 - val_mse: 0.0731
# Epoch 5/60
# 25/25 [==============================] - 7s 276ms/step - loss: 0.0732 - mse: 0.0732 - val_loss: 0.0595 - val_mse: 0.0595
# Epoch 6/60
# 25/25 [==============================] - 7s 281ms/step - loss: 0.0569 - mse: 0.0569 - val_loss: 0.0375 - val_mse: 0.0375
# Epoch 7/60
# 25/25 [==============================] - 7s 276ms/step - loss: 0.0416 - mse: 0.0416 - val_loss: 0.0305 - val_mse: 0.0305
# Epoch 8/60
# 25/25 [==============================] - 7s 278ms/step - loss: 0.0321 - mse: 0.0321 - val_loss: 0.0200 - val_mse: 0.0200
# Epoch 9/60
# 25/25 [==============================] - 7s 278ms/step - loss: 0.0275 - mse: 0.0275 - val_loss: 0.0212 - val_mse: 0.0212
# Epoch 10/60
# 25/25 [==============================] - 7s 276ms/step - loss: 0.0216 - mse: 0.0216 - val_loss: 0.0134 - val_mse: 0.0134
# Epoch 11/60
# 25/25 [==============================] - 7s 284ms/step - loss: 0.0213 - mse: 0.0213 - val_loss: 0.0169 - val_mse: 0.0169
# Epoch 12/60
# 25/25 [==============================] - 7s 277ms/step - loss: 0.0179 - mse: 0.0179 - val_loss: 0.0112 - val_mse: 0.0112
# Epoch 13/60
# 25/25 [==============================] - 7s 277ms/step - loss: 0.0182 - mse: 0.0182 - val_loss: 0.0139 - val_mse: 0.0139
# Epoch 14/60
# 25/25 [==============================] - 7s 276ms/step - loss: 0.0161 - mse: 0.0161 - val_loss: 0.0105 - val_mse: 0.0105
# Epoch 15/60
# 25/25 [==============================] - 7s 275ms/step - loss: 0.0166 - mse: 0.0166 - val_loss: 0.0122 - val_mse: 0.0122
# Epoch 16/60
# 25/25 [==============================] - 7s 274ms/step - loss: 0.0153 - mse: 0.0153 - val_loss: 0.0102 - val_mse: 0.0102
# Epoch 17/60
# 25/25 [==============================] - 7s 277ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.0113 - val_mse: 0.0113
# Epoch 18/60
# 25/25 [==============================] - 7s 276ms/step - loss: 0.0149 - mse: 0.0149 - val_loss: 0.0102 - val_mse: 0.0102
# Epoch 19/60
# 25/25 [==============================] - 7s 276ms/step - loss: 0.0151 - mse: 0.0151 - val_loss: 0.0106 - val_mse: 0.0106
# Epoch 20/60
# 25/25 [==============================] - 7s 277ms/step - loss: 0.0146 - mse: 0.0146 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 21/60
# 25/25 [==============================] - 7s 280ms/step - loss: 0.0147 - mse: 0.0147 - val_loss: 0.0103 - val_mse: 0.0103
# Epoch 22/60
# 25/25 [==============================] - 7s 278ms/step - loss: 0.0144 - mse: 0.0144 - val_loss: 0.0100 - val_mse: 0.0100
# Epoch 23/60
# 25/25 [==============================] - 7s 275ms/step - loss: 0.0144 - mse: 0.0144 - val_loss: 0.0100 - val_mse: 0.0100
# Epoch 24/60
# 25/25 [==============================] - 7s 275ms/step - loss: 0.0143 - mse: 0.0143 - val_loss: 0.0099 - val_mse: 0.0099
# Epoch 25/60
# 25/25 [==============================] - 7s 277ms/step - loss: 0.0142 - mse: 0.0142 - val_loss: 0.0099 - val_mse: 0.0099
# Epoch 26/60
# 25/25 [==============================] - 7s 278ms/step - loss: 0.0141 - mse: 0.0141 - val_loss: 0.0098 - val_mse: 0.0098
# Epoch 27/60
# 25/25 [==============================] - 7s 277ms/step - loss: 0.0141 - mse: 0.0141 - val_loss: 0.0098 - val_mse: 0.0098
# Epoch 28/60
# 25/25 [==============================] - 7s 278ms/step - loss: 0.0140 - mse: 0.0140 - val_loss: 0.0097 - val_mse: 0.0097
# Epoch 29/60
# 25/25 [==============================] - 7s 276ms/step - loss: 0.0140 - mse: 0.0140 - val_loss: 0.0097 - val_mse: 0.0097
# Epoch 30/60
# 25/25 [==============================] - 7s 274ms/step - loss: 0.0139 - mse: 0.0139 - val_loss: 0.0097 - val_mse: 0.0097
# Epoch 31/60
# 25/25 [==============================] - 7s 274ms/step - loss: 0.0139 - mse: 0.0139 - val_loss: 0.0096 - val_mse: 0.0096
# Epoch 32/60
# 25/25 [==============================] - 7s 274ms/step - loss: 0.0138 - mse: 0.0138 - val_loss: 0.0096 - val_mse: 0.0096
# Epoch 33/60
# 25/25 [==============================] - 7s 276ms/step - loss: 0.0138 - mse: 0.0138 - val_loss: 0.0096 - val_mse: 0.0096
# Epoch 34/60
# 25/25 [==============================] - 7s 277ms/step - loss: 0.0137 - mse: 0.0137 - val_loss: 0.0095 - val_mse: 0.0095
# Epoch 35/60
# 25/25 [==============================] - 7s 277ms/step - loss: 0.0137 - mse: 0.0137 - val_loss: 0.0095 - val_mse: 0.0095
# Epoch 36/60
# 25/25 [==============================] - 7s 277ms/step - loss: 0.0136 - mse: 0.0136 - val_loss: 0.0095 - val_mse: 0.0095
# Epoch 37/60
# 25/25 [==============================] - 7s 278ms/step - loss: 0.0136 - mse: 0.0136 - val_loss: 0.0094 - val_mse: 0.0094
# Epoch 38/60
# 25/25 [==============================] - 7s 278ms/step - loss: 0.0136 - mse: 0.0136 - val_loss: 0.0094 - val_mse: 0.0094
# Epoch 39/60
# 25/25 [==============================] - 7s 281ms/step - loss: 0.0135 - mse: 0.0135 - val_loss: 0.0094 - val_mse: 0.0094
# Epoch 40/60
# 25/25 [==============================] - 7s 276ms/step - loss: 0.0135 - mse: 0.0135 - val_loss: 0.0094 - val_mse: 0.0094
# Epoch 41/60
# 25/25 [==============================] - 7s 277ms/step - loss: 0.0135 - mse: 0.0135 - val_loss: 0.0093 - val_mse: 0.0093
# Epoch 42/60
# 25/25 [==============================] - 7s 274ms/step - loss: 0.0135 - mse: 0.0135 - val_loss: 0.0093 - val_mse: 0.0093
# Epoch 43/60
# 25/25 [==============================] - 7s 278ms/step - loss: 0.0134 - mse: 0.0134 - val_loss: 0.0093 - val_mse: 0.0093
# Epoch 44/60
# 25/25 [==============================] - 7s 281ms/step - loss: 0.0134 - mse: 0.0134 - val_loss: 0.0093 - val_mse: 0.0093
# Epoch 45/60
# 25/25 [==============================] - 7s 277ms/step - loss: 0.0134 - mse: 0.0134 - val_loss: 0.0093 - val_mse: 0.0093
# Epoch 46/60
# 25/25 [==============================] - 7s 281ms/step - loss: 0.0134 - mse: 0.0134 - val_loss: 0.0092 - val_mse: 0.0092
# Epoch 47/60
# 25/25 [==============================] - 7s 279ms/step - loss: 0.0133 - mse: 0.0133 - val_loss: 0.0092 - val_mse: 0.0092
# Epoch 48/60
# 25/25 [==============================] - 7s 280ms/step - loss: 0.0133 - mse: 0.0133 - val_loss: 0.0092 - val_mse: 0.0092
# Epoch 49/60
# 25/25 [==============================] - 7s 278ms/step - loss: 0.0133 - mse: 0.0133 - val_loss: 0.0092 - val_mse: 0.0092
# Epoch 50/60
# 25/25 [==============================] - 7s 277ms/step - loss: 0.0133 - mse: 0.0133 - val_loss: 0.0092 - val_mse: 0.0092
# Epoch 51/60
# 25/25 [==============================] - 7s 279ms/step - loss: 0.0132 - mse: 0.0132 - val_loss: 0.0091 - val_mse: 0.0091
# Epoch 52/60
# 25/25 [==============================] - 7s 279ms/step - loss: 0.0132 - mse: 0.0132 - val_loss: 0.0091 - val_mse: 0.0091
# Epoch 53/60
# 25/25 [==============================] - 7s 281ms/step - loss: 0.0132 - mse: 0.0132 - val_loss: 0.0091 - val_mse: 0.0091
# Epoch 54/60
# 25/25 [==============================] - 7s 280ms/step - loss: 0.0132 - mse: 0.0132 - val_loss: 0.0091 - val_mse: 0.0091
# Epoch 55/60
# 25/25 [==============================] - 7s 280ms/step - loss: 0.0132 - mse: 0.0132 - val_loss: 0.0091 - val_mse: 0.0091
# Epoch 56/60
# 25/25 [==============================] - 7s 279ms/step - loss: 0.0131 - mse: 0.0131 - val_loss: 0.0091 - val_mse: 0.0091
# Epoch 57/60
# 25/25 [==============================] - 7s 279ms/step - loss: 0.0131 - mse: 0.0131 - val_loss: 0.0090 - val_mse: 0.0090
# Epoch 58/60
# 25/25 [==============================] - 7s 278ms/step - loss: 0.0131 - mse: 0.0131 - val_loss: 0.0090 - val_mse: 0.0090
# Epoch 59/60
# 25/25 [==============================] - 7s 277ms/step - loss: 0.0131 - mse: 0.0131 - val_loss: 0.0090 - val_mse: 0.0090
# Epoch 60/60
# 25/25 [==============================] - 7s 280ms/step - loss: 0.0131 - mse: 0.0131 - val_loss: 0.0090 - val_mse: 0.0090

# %%
# Test Data Batch 1 , Test Data Batch 2 , Test Data Batch 3
url_test = '/content/drive/MyDrive/Colab Notebooks/Datasets/Test Data Batch 1.csv'
dataset_test_ok = pd.read_csv(url_test)
dataset_test_ok.head()
# read test data
x1_test = dataset_test_ok['x1'].values
x2_test = dataset_test_ok['x2'].values
y_test = dataset_test_ok['y'].values # no need to scale
# convert to [rows, columns] structure
x1_test = x1_test.reshape((len(x1_test), 1))
x2_test = x2_test.reshape((len(x2_test), 1))
y_test = y_test.reshape((len(y_test), 1))
x1_test_scaled = scaler.fit_transform(x1_test)
x2_test_scaled = scaler.fit_transform(x2_test)

# %%
def prep_data(x1_test_scaled , x2_test_scaled , y_test , start , end , last):
    #prepare test data X
    dataset_test = hstack((x1_test_scaled, x2_test_scaled))
    dataset_test_X = dataset_test[start:end, :]
    print("dataset_test_X :",dataset_test_X.shape)
    test_X_new = dataset_test_X.reshape(1,dataset_test_X.shape[0],dataset_test_X.shape[1])
    print("test_X_new :",test_X_new.shape)
#prepare past and groundtruth
    past_data = y_test[:end , :]
    dataset_test_y = y_test[end:last , :]
    scaler1 = MinMaxScaler(feature_range=(0, 1))
    scaler1.fit(dataset_test_y)
    print("dataset_test_y :",dataset_test_y.shape)
    print("past_data :",past_data.shape)
#predictions
    y_pred = model.predict(test_X_new)
    y_pred_inv = scaler1.inverse_transform(y_pred)
    y_pred_inv = y_pred_inv.reshape(n_steps_out,1)
    y_pred_inv = y_pred_inv[:,0]
    print("y_pred :",y_pred.shape)
    print("y_pred_inv :",y_pred_inv.shape)
    
    return y_pred_inv , dataset_test_y , past_data
#start can be any point in the test data (1258)
start = 60
end = start + n_steps_in 
last = end + n_steps_out 
y_pred_inv , dataset_test_y , past_data = prep_data(x1_test_scaled , x2_test_scaled , y_test , start , end , last)
# Out:
# dataset_test_X : (60, 2)
# test_X_new : (1, 60, 2)
# dataset_test_y : (30, 1)
# past_data : (120, 1)
# y_pred : (1, 30)
# y_pred_inv : (30,)

# %%
# Calculate MAE and RMSE
def evaluate_prediction(predictions, actual, model_name , start , end):
    errors = predictions - actual
    mse = np.square(errors).mean()
    rmse = np.sqrt(mse)
    mae = np.abs(errors).mean()
    print("Test Data from {} to {}".format(start, end))
    print('Mean Absolute Error: {:.2f}'.format(mae))
    print('Root Mean Square Error: {:.2f}'.format(rmse))
    print('')
    print('')
evaluate_prediction(y_pred_inv , dataset_test_y, 'LSTM' , start , end)
# Out:
# Test Data from 60 to 120
# Mean Absolute Error: 1.14
# Root Mean Square Error: 1.38

# %%
# Plot history and future
def plot_multistep(history, prediction1 , groundtruth , start , end):
    plt.figure(figsize=(20, 4))
    y_mean = mean(prediction1)
    range_history = len(history)
    range_future = list(range(range_history, range_history + len(prediction1)))
    plt.plot(np.arange(range_history), np.array(history), label='History')
    plt.plot(range_future, np.array(prediction1),label='Forecasted with LSTM')
    plt.plot(range_future, np.array(groundtruth),label='GroundTruth')
    plt.legend(loc='upper right')
    plt.title("Test Data from {} to {} , Mean = {:.2f}".format(start, end, y_mean) ,  fontsize=18)
    plt.xlabel('Time step' ,  fontsize=18)
    plt.ylabel('y-value' , fontsize=18)
plot_multistep(past_data , y_pred_inv , dataset_test_y , start , end)

# %%
for i in range(120,240,60):
    start = i
    end = start + n_steps_in 
    last = end + n_steps_out 
    y_pred_inv , dataset_test_y , past_data = prep_data(x1_test_scaled , x2_test_scaled , y_test , start , end , last) 
    evaluate_prediction(y_pred_inv , dataset_test_y, 'LSTM' , start , end) 
    plot_multistep(past_data , y_pred_inv , dataset_test_y , start , end)
# Out:
# dataset_test_X : (60, 2)
# test_X_new : (1, 60, 2)
# dataset_test_y : (30, 1)
# past_data : (180, 1)
# y_pred : (1, 30)
# y_pred_inv : (30,)
# Test Data from 120 to 180
# Mean Absolute Error: 0.45
# Root Mean Square Error: 0.51
#
#
# dataset_test_X : (60, 2)
# test_X_new : (1, 60, 2)
# dataset_test_y : (30, 1)
# past_data : (240, 1)
# y_pred : (1, 30)
# y_pred_inv : (30,)
# Test Data from 180 to 240
# Mean Absolute Error: 0.24
# Root Mean Square Error: 0.29
